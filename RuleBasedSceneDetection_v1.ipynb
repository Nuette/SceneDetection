# %% [markdown]
# <a href="https://colab.research.google.com/github/Nuette/SceneDetection/blob/main/RuleBasedSceneDetection_v1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install spacy coreferee
# !python -m spacy download en_core_web_lg
# !python -m coreferee install en
# Out:
# Requirement already satisfied: spacy in /usr/local/lib/python3.10/dist-packages (3.7.5)
# Collecting coreferee
#   Downloading coreferee-1.4.1-py3-none-any.whl.metadata (2.5 kB)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.10/dist-packages (from spacy) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in /usr/local/lib/python3.10/dist-packages (from spacy) (8.2.5)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.10/dist-packages (from spacy) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.10/dist-packages (from spacy) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.10/dist-packages (from spacy) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (0.4.1)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (0.12.5)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (4.66.5)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (2.32.3)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /usr/local/lib/python3.10/dist-packages (from spacy) (2.9.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from spacy) (3.1.4)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from spacy) (75.1.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (24.1)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (3.4.1)
# Requirement already satisfied: numpy>=1.19.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (1.26.4)
# Collecting spacy
#   Downloading spacy-3.5.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (25 kB)
# Collecting thinc<8.2.0,>=8.1.8 (from spacy)
#   Downloading thinc-8.1.12-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (15 kB)
# Collecting typer<0.10.0,>=0.3.0 (from spacy)
#   Downloading typer-0.9.4-py3-none-any.whl.metadata (14 kB)
# Collecting pathy>=0.10.0 (from spacy)
#   Downloading pathy-0.11.0-py3-none-any.whl.metadata (16 kB)
# Collecting smart-open<7.0.0,>=5.2.1 (from spacy)
#   Downloading smart_open-6.4.0-py3-none-any.whl.metadata (21 kB)
# Collecting pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4 (from spacy)
#   Downloading pydantic-1.10.18-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (152 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 152.2/152.2 kB 3.6 MB/s eta 0:00:00
# Requirement already satisfied: language-data>=1.2 in /usr/local/lib/python3.10/dist-packages (from langcodes<4.0.0,>=3.2.0->spacy) (1.2.0)
# Collecting pathlib-abc==0.1.1 (from pathy>=0.10.0->spacy)
#   Downloading pathlib_abc-0.1.1-py3-none-any.whl.metadata (18 kB)
# Requirement already satisfied: typing-extensions>=4.2.0 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4->spacy) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (2024.8.30)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.10/dist-packages (from thinc<8.2.0,>=8.1.8->spacy) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from thinc<8.2.0,>=8.1.8->spacy) (0.1.5)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.10/dist-packages (from typer<0.10.0,>=0.3.0->spacy) (8.1.7)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->spacy) (3.0.2)
# Requirement already satisfied: marisa-trie>=0.7.7 in /usr/local/lib/python3.10/dist-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy) (1.2.1)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from weasel<0.5.0,>=0.1.0->spacy) (0.20.0)
# Downloading coreferee-1.4.1-py3-none-any.whl (182 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 182.6/182.6 kB 8.5 MB/s eta 0:00:00
# Downloading spacy-3.5.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (6.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.6/6.6 MB 6.5 MB/s eta 0:00:00
# Downloading pathy-0.11.0-py3-none-any.whl (47 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.3/47.3 kB 3.0 MB/s eta 0:00:00
# Downloading pathlib_abc-0.1.1-py3-none-any.whl (23 kB)
# Downloading pydantic-1.10.18-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 61.7 MB/s eta 0:00:00
# Downloading smart_open-6.4.0-py3-none-any.whl (57 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.0/57.0 kB 3.5 MB/s eta 0:00:00
# Downloading thinc-8.1.12-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (919 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 919.6/919.6 kB 41.8 MB/s eta 0:00:00
# Downloading typer-0.9.4-py3-none-any.whl (45 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 3.1 MB/s eta 0:00:00
# Installing collected packages: typer, smart-open, pydantic, pathlib-abc, pathy, thinc, spacy, coreferee
#   Attempting uninstall: typer
#     Found existing installation: typer 0.12.5
#     Uninstalling typer-0.12.5:
#       Successfully uninstalled typer-0.12.5
#   Attempting uninstall: smart-open
#     Found existing installation: smart-open 7.0.5
#     Uninstalling smart-open-7.0.5:
#       Successfully uninstalled smart-open-7.0.5
#   Attempting uninstall: pydantic
#     Found existing installation: pydantic 2.9.2
#     Uninstalling pydantic-2.9.2:
#       Successfully uninstalled pydantic-2.9.2
#   Attempting uninstall: thinc
#     Found existing installation: thinc 8.2.5
#     Uninstalling thinc-8.2.5:
#       Successfully uninstalled thinc-8.2.5
#   Attempting uninstall: spacy
#     Found existing installation: spacy 3.7.5
#     Uninstalling spacy-3.7.5:
#       Successfully uninstalled spacy-3.7.5
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# albumentations 1.4.15 requires pydantic>=2.7.0, but you have pydantic 1.10.18 which is incompatible.
# en-core-web-sm 3.7.1 requires spacy<3.8.0,>=3.7.2, but you have spacy 3.5.4 which is incompatible.
# Successfully installed coreferee-1.4.1 pathlib-abc-0.1.1 pathy-0.11.0 pydantic-1.10.18 smart-open-6.4.0 spacy-3.5.4 thinc-8.1.12 typer-0.9.4
# 2024-10-24 08:41:09.523770: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-10-24 08:41:09.549686: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-10-24 08:41:09.557253: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-10-24 08:41:09.574305: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-10-24 08:41:10.971992: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Collecting en-core-web-lg==3.5.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_lg-3.5.0/en_core_web_lg-3.5.0-py3-none-any.whl (587.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 587.7/587.7 MB 1.3 MB/s eta 0:00:00
# Requirement already satisfied: spacy<3.6.0,>=3.5.0 in /usr/local/lib/python3.10/dist-packages (from en-core-web-lg==3.5.0) (3.5.4)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (3.0.9)
# Requirement already satisfied: thinc<8.2.0,>=8.1.8 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (8.1.12)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (2.0.10)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (0.9.4)
# Requirement already satisfied: pathy>=0.10.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (0.11.0)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (6.4.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (4.66.5)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (1.26.4)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (2.32.3)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (1.10.18)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (3.1.4)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (75.1.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (24.1)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (3.4.1)
# Requirement already satisfied: language-data>=1.2 in /usr/local/lib/python3.10/dist-packages (from langcodes<4.0.0,>=3.2.0->spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (1.2.0)
# Requirement already satisfied: pathlib-abc==0.1.1 in /usr/local/lib/python3.10/dist-packages (from pathy>=0.10.0->spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (0.1.1)
# Requirement already satisfied: typing-extensions>=4.2.0 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4->spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (2024.8.30)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.10/dist-packages (from thinc<8.2.0,>=8.1.8->spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from thinc<8.2.0,>=8.1.8->spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (0.1.5)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.10/dist-packages (from typer<0.10.0,>=0.3.0->spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (8.1.7)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (3.0.2)
# Requirement already satisfied: marisa-trie>=0.7.7 in /usr/local/lib/python3.10/dist-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (1.2.1)
# Installing collected packages: en-core-web-lg
# Successfully installed en-core-web-lg-3.5.0
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_lg')
# 2024-10-24 08:41:52.739121: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-10-24 08:41:52.766647: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-10-24 08:41:52.773750: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Collecting https://github.com/richardpaulhudson/coreferee/raw/master/models/coreferee_model_en.zip
#   Downloading https://github.com/richardpaulhudson/coreferee/raw/master/models/coreferee_model_en.zip (65.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.4/65.4 MB 10.2 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Building wheels for collected packages: coreferee-model-en
#   Building wheel for coreferee-model-en (pyproject.toml) ... done
#   Created wheel for coreferee-model-en: filename=coreferee_model_en-1.0.0-py3-none-any.whl size=65422507 sha256=4a713c2a1358fcbc72158a0422e287ff0138aa472def0c8e75f47cf72ce6a800
#   Stored in directory: /tmp/pip-ephem-wheel-cache-ubzubbqg/wheels/87/ca/93/b7c91eabb7b65a4200a75ea842a7009810982015d2dedfdc54
# Successfully built coreferee-model-en
# Installing collected packages: coreferee-model-en
# Successfully installed coreferee-model-en-1.0.0

# %%
import spacy
import coreferee

# Load the spaCy model
nlp = spacy.load("en_core_web_lg")
nlp.add_pipe('coreferee')

# %%
file_path = 'The_adventures_of_the_Italian_nobleman.txt'

with open(file_path, 'r', encoding='utf-8') as file:
    text = file.read()

# %% [markdown]
# Function to detect characters using coreferee

# %%
def get_character_mentions(doc):
    character_mentions = {}
    for chain in doc._.coref_chains.chains:
        main_mention = chain[0]
        main_mention_span = doc[main_mention.token_indexes[0]:main_mention.token_indexes[-1] + 1]

        if main_mention_span.root.pos_ == "PROPN":
            mentions = []
            for mention in chain:
                mention_span = doc[mention.token_indexes[0]:mention.token_indexes[-1] + 1]
                mentions.append(mention_span.text)
            character_mentions[main_mention_span.text] = mentions
    return character_mentions

# %% [markdown]
# Function to detect place

# %%
def get_place_mentions(doc):
    places = set(ent.text for ent in doc.ents if ent.label_ in ["GPE", "LOC"])
    return places

# %% [markdown]
# Function to identify time mentions

# %%
def get_time_mentions(doc):
    times = set(ent.text for ent in doc.ents if ent.label_ in ["DATE", "TIME"])
    return times

# %% [markdown]
# Function to detect summaries or scenic descriptions

# %%
def is_summary_or_description(doc):
    adjectives = [token for token in doc if token.pos_ == "ADJ"]
    action_verbs = [token for token in doc if token.pos_ == "VERB" and token.tag_ in ["VBD", "VB"]]

    # Heuristic: If there are more adjectives than action verbs, it's likely a description
    return len(adjectives) > len(action_verbs) * 2

# %% [markdown]
# Replace coreferent mentions only at the token level to avoid replacing parts of words

# %%
# Function to replace coreferent mentions using coreferee
def replace_coreferences(doc):
    coref_resolved_text = []
    for token in doc:
        # Check if the token is part of a coreference chain
        if token._.coref_chains:
            # Find the first coreference chain this token belongs to
            for chain in doc._.coref_chains.chains:
                if token.i in chain:
                    # Replace with the main mention of the chain
                    main_entity = doc[chain[0].token_indexes[0]:chain[0].token_indexes[-1] + 1]
                    coref_resolved_text.append(main_entity.text)
                    break
        else:
            coref_resolved_text.append(token.text)
    return " ".join(coref_resolved_text)

# %% [markdown]
# # Apply the spaCy pipeline and segment text using a sliding window

# %%
window_size = 5

previous_characters = set()
previous_time = set()
previous_place = set()

character_memory = set()
character_memory_window_size = 3  # Number of windows to retain characters. Experiment with this untill a good output is given.
segments = []
current_segment = []
current_type = 'scene'

sentences = [sent.text.strip() for sent in nlp(text).sents]
i = 0
while i < len(sentences):
    window = sentences[i:i + window_size]
    window_text = " ".join(window)
    window_doc = nlp(window_text)

    resolved_window_text = replace_coreferences(window_doc)
    window_doc_resolved = nlp(resolved_window_text)

    # Extract characters, time, and places
    window_characters = {ent.text for ent in window_doc_resolved.ents if ent.label_ == "PERSON"}
    window_times = get_time_mentions(window_doc_resolved)
    window_places = get_place_mentions(window_doc_resolved)

    print(f"Times detected in Window {i // window_size + 1}: {window_times}")
    print(f"Places detected in Window {i // window_size + 1}: {window_places}")

    # Check if the current window contains a non-scene
    summary_detected = is_summary_or_description(window_doc_resolved)

    if summary_detected:
        print(f"Non-Scene (Summary/Description) detected in Window {i // window_size + 1}")

    character_memory.update(window_characters)
    if len(character_memory) > character_memory_window_size:
        character_memory = set(list(character_memory)[-character_memory_window_size:])

    # Check for scene boundary or non-scene detection
    if (not window_characters.issubset(character_memory) or
        window_times != previous_time or
        window_places != previous_place or
        summary_detected):

        if current_segment:
            segments.append({
                'text': " ".join(current_segment),
                'type': current_type
            })
            current_segment = []

        # If the current window is a non-scene
        if summary_detected:
            current_type = 'non-scene'
        else:
            current_type = 'scene'

        # Clear character memory if it's a completely new scene
        character_memory.clear()

    # Add the current window text to the current segment
    current_segment.append(resolved_window_text)

    # Update values
    previous_characters = window_characters
    previous_time = window_times
    previous_place = window_places

    i += window_size

if current_segment:
    segments.append({
        'text': " ".join(current_segment),
        'type': current_type
    })
# Out:
# Times detected in Window 1: {'one particular evening', 'early June'}
# Places detected in Window 1: set()
# Non-Scene (Summary/Description) detected in Window 1
# Times detected in Window 2: set()
# Places detected in Window 2: set()
# Times detected in Window 3: set()
# Places detected in Window 3: set()
# Times detected in Window 4: set()
# Places detected in Window 4: set()
# Times detected in Window 5: set()
# Places detected in Window 5: set()
# Times detected in Window 6: {'a few weeks ago'}
# Places detected in Window 6: set()
# Times detected in Window 7: set()
# Places detected in Window 7: set()
# Times detected in Window 8: set()
# Places detected in Window 8: {'St. John ’s'}
# Times detected in Window 9: set()
# Places detected in Window 9: set()
# Times detected in Window 10: {'about half an hour ago'}
# Places detected in Window 10: set()
# Times detected in Window 11: set()
# Places detected in Window 11: set()
# Times detected in Window 12: set()
# Places detected in Window 12: set()
# Times detected in Window 13: set()
# Places detected in Window 13: set()
# Times detected in Window 14: set()
# Places detected in Window 14: set()
# Times detected in Window 15: set()
# Places detected in Window 15: set()
# Times detected in Window 16: set()
# Places detected in Window 16: set()
# Times detected in Window 17: {'a minute'}
# Places detected in Window 17: set()
# Times detected in Window 18: set()
# Places detected in Window 18: set()
# Times detected in Window 19: set()
# Places detected in Window 19: set()
# Times detected in Window 20: set()
# Places detected in Window 20: set()
# Times detected in Window 21: set()
# Places detected in Window 21: set()
# Times detected in Window 22: set()
# Places detected in Window 22: set()
# Times detected in Window 23: set()
# Places detected in Window 23: set()
# Times detected in Window 24: {'Just about eight o’clock'}
# Places detected in Window 24: set()
# Times detected in Window 25: set()
# Places detected in Window 25: set()
# Times detected in Window 26: set()
# Places detected in Window 26: set()
# Times detected in Window 27: set()
# Places detected in Window 27: set()
# Times detected in Window 28: {'five minutes'}
# Places detected in Window 28: set()
# Times detected in Window 29: {'the previous morning'}
# Places detected in Window 29: set()
# Times detected in Window 30: set()
# Places detected in Window 30: set()
# Times detected in Window 31: {'This evening', 'morrow', 'eight o’clock'}
# Places detected in Window 31: set()
# Times detected in Window 32: {'about 8.30'}
# Places detected in Window 32: set()
# Times detected in Window 33: {'that hour'}
# Places detected in Window 33: set()
# Non-Scene (Summary/Description) detected in Window 33
# Times detected in Window 34: set()
# Places detected in Window 34: set()
# Non-Scene (Summary/Description) detected in Window 34
# Times detected in Window 35: set()
# Places detected in Window 35: {'Continong'}
# Times detected in Window 36: set()
# Places detected in Window 36: set()
# Times detected in Window 37: set()
# Places detected in Window 37: set()
# Times detected in Window 38: set()
# Places detected in Window 38: set()
# Times detected in Window 39: set()
# Places detected in Window 39: set()
# Times detected in Window 40: set()
# Places detected in Window 40: set()
# Times detected in Window 41: set()
# Places detected in Window 41: set()
# Times detected in Window 42: set()
# Places detected in Window 42: set()
# Times detected in Window 43: {'the Continent two days', 'the previous morning', 'the evening'}
# Places detected in Window 43: set()
# Times detected in Window 44: {'nine that evening'}
# Places detected in Window 44: set()
# Times detected in Window 45: {'one morning', 'eleven o’clock'}
# Places detected in Window 45: set()
# Times detected in Window 46: set()
# Places detected in Window 46: set()
# Times detected in Window 47: {'A few minutes later'}
# Places detected in Window 47: set()
# Non-Scene (Summary/Description) detected in Window 47
# Times detected in Window 48: {'the morning of Tuesday the 9th'}
# Places detected in Window 48: set()
# Times detected in Window 49: set()
# Places detected in Window 49: set()
# Times detected in Window 50: set()
# Places detected in Window 50: set()
# Times detected in Window 51: set()
# Places detected in Window 51: {'England'}
# Times detected in Window 52: {'Tuesday', 'morning'}
# Places detected in Window 52: set()
# Times detected in Window 53: set()
# Places detected in Window 53: {'England', 'Italy'}
# Times detected in Window 54: {'that morning'}
# Places detected in Window 54: set()
# Non-Scene (Summary/Description) detected in Window 54
# Times detected in Window 55: set()
# Places detected in Window 55: set()
# Times detected in Window 56: set()
# Places detected in Window 56: set()
# Times detected in Window 57: set()
# Places detected in Window 57: set()
# Non-Scene (Summary/Description) detected in Window 57
# Times detected in Window 58: set()
# Places detected in Window 58: set()
# Times detected in Window 59: {'half - past', 'the of June', 'eight o’clock'}
# Places detected in Window 59: set()
# Times detected in Window 60: {'some day'}
# Places detected in Window 60: set()
# Times detected in Window 61: set()
# Places detected in Window 61: set()
# Times detected in Window 62: set()
# Places detected in Window 62: set()
# Times detected in Window 63: {'the morning', 'about eight o’clock'}
# Places detected in Window 63: set()
# Times detected in Window 64: set()
# Places detected in Window 64: set()
# Non-Scene (Summary/Description) detected in Window 64
# Times detected in Window 65: set()
# Places detected in Window 65: set()
# Times detected in Window 66: set()
# Places detected in Window 66: set()
# Times detected in Window 67: set()
# Places detected in Window 67: set()

# %% [markdown]
# # Display the segmented scenes and non-scenes

# %%
# Display the segmented scenes and non-scenes
for i, segment in enumerate(segments, 1):
    segment_type = segment['type']
    print(f"\nSegment {i} ({segment_type.capitalize()}):\n{segment['text']}\n")
# Out:
# Segment 1 (Non-scene):
# and I had many friends and acquaintances of an informal nature . Amongst these was to be numbered Dr. Hawker , a near neighbour of ours , and a member of the medical profession . It was the genial doctor ’s habit to drop in sometimes of an evening and have a chat with , of whose genius was an ardent admirer . The , frank and unsuspicious to the last degree , admired the talents so far removed from own . On one particular evening in early June , arrived about half - past eight and settled down to a comfortable discussion on the cheery topic of the prevalence of arsenical poisoning in crimes .
#
#
# Segment 2 (Scene):
# It must have been about a quarter of an hour later when the door of our sitting - room flew open , and a distracted precipitated into the room . “ Oh , doctor , you ’re wanted ! Such a terrible . gave me a turn , did indeed . ” I recognized in our new visitor Dr. Hawker ’s housekeeper , Miss Rider . The doctor was a bachelor , and lived in a gloomy old house a few streets away . The usually placid Miss was now in a state bordering on incoherence . “ What terrible voice ?
#  Who is , and what ’s the trouble ? ” “ was the telephone , doctor . I answered — and a voice spoke . ‘ Help , ’ said . ‘ Doctor — . ’ve killed me ! ’ Then sort of tailed away . ‘ Who ’s speaking ? ’ I said . ‘ Who ’s speaking ? ’ Then I got a reply , just a whisper , it seemed , ‘ Foscatine’—something like that—‘Regent ’s Court . ’ ” The doctor uttered an exclamation . “ Count Foscatini .
#
#
# Segment 3 (Scene):
# He has a flat in Regent ’s Court . I must go at once . What can have happened ? ” “ A patient of yours ? ” asked . “ I attended for some slight ailment a few weeks ago .
#
#
# Segment 4 (Scene):
# An Italian , but speaks English perfectly . Well , I must wish you good night , Monsieur Poirot , unless — — ” hesitated . “ I perceive the thought in your mind , ” said Poirot , smiling . “ I shall be delighted to accompany you . Hastings , run down and get hold of a taxi . ”
#
#
# Segment 5 (Scene):
# always make sought for when one is particularly pressed for time , but I captured one at last , and we were soon bowling along in the direction of Regent ’s Park . Regent ’s Court was a new block of , situated just off St. John ’s Wood Road . had only recently been built , and contained the latest service devices . There was no one in the hall . The doctor pressed the lift - bell impatiently , and when the lift arrived questioned the uniformed attendant sharply .
#
#
# Segment 6 (Scene):
# “ Flat II . Count . There ’s been an there , I understand . ” The man stared at . “ First I ’ve heard of .
#
#
# Segment 7 (Scene):
# Mr. — that ’s Count Foscatini ’s man — went out about half an hour ago , and said nothing . ” “ Is the alone in the flat ? ” “ No , sir , ’s got two dining with . ” “ What are like ? ” I asked eagerly .
#
#
# Segment 8 (Scene):
# We were in the lift now , ascending rapidly to the second floor , on which Flat was situated . “ I did n’t see myself , sir , but I understand that were foreign gentlemen . ” He pulled back the iron door , and we stepped out on the landing . No .
